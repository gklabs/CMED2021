# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Make crfsuite.exe executable

# %%
# !chmod +x /content/drive/MyDrive/fable/crfsuite/bin/crfsuite

# %% [markdown]
# Generate new fable models based on finalized traning files: temp_x

# %%
import os
os.system('/content/drive/MyDrive/fable/crfsuite/bin/crfsuite learn -m /content/drive/MyDrive/fable/data/newModel_0.model /content/drive/MyDrive/fable/data/temp_0')
os.system('/content/drive/MyDrive/fable/crfsuite/bin/crfsuite learn -m /content/drive/MyDrive/fable/data/newModel_1.model /content/drive/MyDrive/fable/data/temp_1')
os.system('/content/drive/MyDrive/fable/crfsuite/bin/crfsuite learn -m /content/drive/MyDrive/fable/data/newModel_2.model /content/drive/MyDrive/fable/data/temp_2')
os.system('/content/drive/MyDrive/fable/crfsuite/bin/crfsuite learn -m /content/drive/MyDrive/fable/data/newModel_3.model /content/drive/MyDrive/fable/data/temp_3')
# Out:
# 32512
